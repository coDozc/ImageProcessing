# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
image_path = "C:\\Users\\ozcan\\Downloads\\library_koca.jpg"
img = cv.imread(image_path)
print(img.shape)
plt.imshow(img)
plt.show()
# Out:
# (768, 1024, 3)

# %%
gray_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
denoised_img = cv.fastNlMeansDenoising(gray_img, None, h=10, searchWindowSize = 21, templateWindowSize = 7)

# %%
blur_img = cv.GaussianBlur(denoised_img, (0,0), 3)
sharpened_img = cv.addWeighted(denoised_img, 1.5, blur_img, -0.5, 0)

# %%
colorized_img = cv.cvtColor(sharpened_img, cv.COLOR_GRAY2BGR)

# %%
plt.figure(figsize=(10, 7))

plt.subplot(231), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB)), plt.title('Original Image')
plt.subplot(232), plt.imshow(gray_img, cmap='gray'), plt.title('Grayscale Image')
plt.subplot(233), plt.imshow(denoised_img, cmap='gray'), plt.title('Denoised Image')
plt.subplot(234), plt.imshow(blur_img, cmap='gray'), plt.title('Blurred Image')
plt.subplot(235), plt.imshow(colorized_img), plt.title('Unsharp Masking')

plt.show()

# %%
cv.imwrite('unsharp_masking_librarykoca.jpg', colorized_img)
# Out:
# True
